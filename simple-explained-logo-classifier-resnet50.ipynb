000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Zara/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Zara/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Zara/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Zara/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/BMW/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/BMW/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/BMW/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/BMW/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nutella/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nutella/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nutella/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nutella/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/McDonald/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/McDonald/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/McDonald/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/McDonald/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/McDonald/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nescafe/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nescafe/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nescafe/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nescafe/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Nescafe/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Instagram/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Instagram/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Instagram/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Instagram/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Instagram/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Pay pal/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Pay pal/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Pay pal/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/output/Pay pal/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Hp/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Fila/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Twitter/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Heinz/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Netflix/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cowbell/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cowbell/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cowbell/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cowbell/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cowbell/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cowbell/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/YouTube/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Dominos/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Starbucks/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/MnM/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lg/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Android/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Huawei/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Peak milk/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tiktok/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nike/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Apple/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Microsoft/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Samsung/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Burger King/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oral b/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Goya oil/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Goya oil/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Goya oil/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Goya oil/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Goya oil/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Goya oil/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Gillette/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Bic/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Honda/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pringles/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chrome/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn dew/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mars/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mars/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mars/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mars/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mars/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mars/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Amazon/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Marvel/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Google/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/NASA/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/NASA/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/NASA/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/NASA/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/NASA/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/NASA/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Rolex/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle milo/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pepsi/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Levis/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mercedes Benz/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nestle/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Kfc/000005.jpg
# ...
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Puma/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Puma/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lays/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Cadbury/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Ariel/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Ariel/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Ariel/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Ariel/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Ariel/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Ariel/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Krisspy Kreme/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/PlayStation/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Sprite/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Guinness/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Chevrolet/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Adidas/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Tesla/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Reebok/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Coca Cola/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Mtn/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Lipton/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oreo/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oreo/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oreo/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oreo/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oreo/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Oreo/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Zara/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/BMW/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nutella/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/McDonald/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Nescafe/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/scal_000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/000005.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Instagram/scal_000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/scal_000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/scal_000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/scal_000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/000004.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/000003.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/000002.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/000001.jpg
# /kaggle/input/fakereal-logo-detection-dataset/genLogoOutput/Pay pal/scal_000003.jpg

# %% [markdown]
# **Importing Dependencies**

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
import pandas as pd
import os
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Modifying CSV - Data-Preprocessing**

# %%
import csv

# Open the CSV file
with open('/kaggle/input/fakereal-logo-detection-dataset/file_mapping.csv', 'r') as file:
    reader = csv.reader(file)
    rows = list(reader)

# Iterate over the rows and replace backslashes with forward slashes
for row in rows:
    row[0] = row[0].replace('\\', '/')

# Save the modified CSV file
with open('modified_csv_file.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(rows)

# %% [markdown]
# **Data-Loader**

# %%
class LogoDataset(Dataset):
    def __init__(self, csv_path, root_dir, transform=None):
        self.data = pd.read_csv(csv_path)
        self.root_dir = root_dir
        self.transform = transform

        # self.vectorizer = CountVectorizer()

        # Fit the vectorizer on taglines
        # self.data['Tagline'].fillna('', inplace=True)

        # self.vectorizer = CountVectorizer()
        # self.vectorizer.fit(self.data['Tagline'])
                
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.data['Filename'][idx])
        image = Image.open(img_path).convert('RGB')
        label_name = self.data['Label'][idx]
        # tagline = self.data['Tagline'][idx]
        
        if label_name == "Genuine":
            label = 0
        else:
            label = 1
            
        if self.transform:
            image = self.transform(image)
        
        # tagline_vector = self.vectorizer.transform([tagline]).toarray()
        # tagline_tensor = torch.tensor(tagline_vector, dtype=torch.float32).squeeze()
            
        return image, label #,tagline_tensor

# %%
dataset_path = '/kaggle/input/fakereal-logo-detection-dataset'
csv_file = '/kaggle/working/modified_csv_file.csv'

# %% [markdown]
# **Data Augmentation - Applying Tranformation**

# %%
image_transforms = transforms.Compose([
    transforms.Resize((70, 70)),
    transforms.RandomCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),
    transforms.RandomRotation(30),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406],
    #                      std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# **Loading Data**

# %%
logo_dataset = LogoDataset(csv_file, dataset_path, transform=image_transforms)

# %%
batch_size = 32
dataloader = DataLoader(logo_dataset, batch_size=batch_size, shuffle=True)

# %%
model = models.resnet50(pretrained=True)
num_classes = 2  # Adjust this based on the number of classes in your dataset
in_features = model.fc.in_features
model.fc = torch.nn.Linear(in_features, num_classes)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 238MB/s]

# %% [markdown]
# **Initializing Loss and Fine tuning model**

# %%
# embedding_dim = 2048  # Adjust the dimensionality of the embedding to match the model's fc layer
# tagline_embedding = torch.nn.Linear(len(logo_dataset.vectorizer.vocabulary_), embedding_dim)

model.fc = torch.nn.Linear(in_features, num_classes)

# Define the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Set the device for training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# tagline_embedding = tagline_embedding.to(device)

# %% [markdown]
# **Model training till 25 epochs**

# %%
num_epochs = 25
save_interval = 5

for epoch in range(num_epochs):
    running_loss = 0.0
    for images, labels in dataloader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    epoch_loss = running_loss / len(dataloader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    if (epoch + 1) % save_interval == 0:
            # Save the trained model
            torch.save(model.state_dict(), f'logo_classification_model_epoch{epoch+1}.pth')
# Out:
# Epoch [1/25], Loss: 0.9087
# Epoch [2/25], Loss: 0.5350
# Epoch [3/25], Loss: 0.4442
# Epoch [4/25], Loss: 0.3651
# Epoch [5/25], Loss: 0.3374
# Epoch [6/25], Loss: 0.3742
# Epoch [7/25], Loss: 0.2506
# Epoch [8/25], Loss: 0.3070
# Epoch [9/25], Loss: 0.3307
# Epoch [10/25], Loss: 0.2754
# Epoch [11/25], Loss: 0.3104
# Epoch [12/25], Loss: 0.3001
# Epoch [13/25], Loss: 0.4368
# Epoch [14/25], Loss: 0.3452
# Epoch [15/25], Loss: 0.3521
# Epoch [16/25], Loss: 0.3281
# Epoch [17/25], Loss: 0.2962
# Epoch [18/25], Loss: 0.2439
# Epoch [19/25], Loss: 0.2233
# Epoch [20/25], Loss: 0.2409
# Epoch [21/25], Loss: 0.2214
# Epoch [22/25], Loss: 0.2017
# Epoch [23/25], Loss: 0.2043
# Epoch [24/25], Loss: 0.1616
# Epoch [25/25], Loss: 0.1923

# %% [markdown]
# **Test - Inference**

# %%
import torch
from torchvision import transforms, models
from PIL import Image

# %% [markdown]
# **Loading pre-trained model**

# %%
model_path = '/kaggle/working/logo_classification_model_epoch25.pth'

# Load the model
model = models.resnet50(pretrained=False)
num_classes = 2  
in_features = model.fc.in_features
model.fc = torch.nn.Linear(in_features, num_classes)
model.load_state_dict(torch.load(model_path))
model.eval()
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %% [markdown]
# **Set the device for inference and apply transformation**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

image_transforms = transforms.Compose([
    transforms.Resize((70, 70)),
    transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# **Function to perform inference on a single image**

# %%
def classify_logo(image_path):
    image = Image.open(image_path).convert('RGB')
    image = image_transforms(image).unsqueeze(0)
    image = image.to(device)

    with torch.no_grad():
        outputs = model(image)

    _, predicted = torch.max(outputs.data, 1)
    class_index = predicted.item()
    classes = ['genuine', 'fake']
    class_label = classes[class_index]

    return class_label

# %% [markdown]
# **Example Usage**

# %%
test_image_path = '/kaggle/input/test-image/download.png'
predicted_class = classify_logo(test_image_path)
print("Predicted class:", predicted_class)
# Out:
# Predicted class: fake
